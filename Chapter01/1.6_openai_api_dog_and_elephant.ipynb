# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
from openai import OpenAI

client = OpenAI(api_key=OPENAI_API_KEY)
client

# %%
from openai import OpenAI

client = OpenAI(api_key=OPENAI_API_KEY)

response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        {"role": "system",
         "content": "당신은 뛰어난 이야기 작가입니다."},
        {"role": "user",
         "content": "강아지와 코끼리가 친구 관계를 끝내는 짧은 어린이 이야기를 써주세요."}
    ]
)

print(response.output[0].content[0].text)
# Out:
# ### 강아지와 코끼리의 이별 이야기
#
# 옛날 옛적, 푸른 초원에 강아지 '루비'와 코끼리 '엘리'가 살았어요. 루비는 항상 행복한 미소를 짓고, 엘리는 그 미소를 보며 마음이 따뜻해졌답니다. 둘은 매일 같이 놀고, 맛있는 간식을 나누며 친구로 지냈어요.
#
# 하지만 어느 날, 루비는 자신의 작은 꿈을 이루고 싶어졌어요. "나는 무지갯빛 나비처럼 높이 날고 싶어!"라고 외쳤죠. 엘리는 그런 루비를 응원해 주었지만, 루비는 점점 새로운 꿈에만 신경을 쓰기 시작했어요.
#
# 루비는 나무 위에서 뛰어놀고, 높은 언덕을 올라가며 날아오르는 연습을 했어요. 그런데 엘리는 지치고 슬펐어요. "루비, 나와 함께 놀지 않을래?"라고 물어보았지만, 루비는 눈을 빛내며 대답했어요. "나는 날 수 있어야 해! 조금만 더 혼자 해볼게!"
#
# 시간이 지나면서 둘의 관계는 소원해졌고, 루비는 날기 위해 더 많은 시간을 혼자 보내야 했어요. 하루하루 점점 거리가 멀어지는 느낌이었죠. 엘리는 울적해졌지만, 루비의 꿈을 응원하며 이해하려고 노력했어요.
#
# 그러던 어느 날, 루비는 결국 높은 나무 꼭대기에 올라갔지만, 날지 못하고 떨어질까 두려웠어요. 그때, 엘리가 크게 소리쳤어요. "루비! 나에게 와! 함께 해보자!" 루비는 잠시 고민했지만, 결국 엘리에게로 뛰어갔어요. 그 순간, 둘은 서로의 손을 잡고 큰 웃음을 터뜨렸어요.
#
# 루비는 깨달았어요. "친구와 함께하는 시간이 더 행복해!" 그리고 엘리도 알게 되었죠. "서로를 응원하고 지켜주는 것이 진정한 우정이구나!"
#
# 결국, 루비와 엘리는 다시 가까워졌고, 함께하는 놀이터에서 서로의 꿈을 응원하며 즐거운 시간을 보냈답니다.
#
# 이렇게 두 친구는 다시 웃으며 자주 만나게 되었어요. 강아지와 코끼리의 우정은 서로의 꿈을 지지하는 것으로 이어졌습니다.
#
# ### 끝.
